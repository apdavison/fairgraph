# %% [markdown]
# # Setup and Imports

# %%
# %%capture
# !rm -rf fairgraph
# !git clone https://github.com/GMattheisen/fairgraph.git
# !pip install -r ./fairgraph/requirements.txt
# !pip install -U ./fairgraph

# %%
from fairgraph import KGClient
import os
import re
import io
import logging
from datetime import date, datetime
from pprint import pprint
import yaml
from collections import defaultdict
import requests
import numpy as np
from neo.io import get_io, Spike2IO, NeoMatlabIO, RawBinarySignalIO, NeoHdf5IO
from fairgraph import KGClient
from fairgraph.commons import (Species, Handedness, Sex, Strain, Age, Genotype, QuantitativeValue, 
    BrainRegion, CellType, QuantitativeValueRange, StimulusType)
from fairgraph.core import (Person, Identifier, Material, Organization, Address, Subject, Protocol, Step, 
    use_namespace)
from fairgraph.experiment import (Slice, BrainSlicingActivity, Device, ElectrophysiologicalStimulation,  
    ElectrophysiologicalStimulus)
from fairgraph.electrophysiology import (PatchedSlice, PatchedCell, PatchedCellCollection, 
    PatchClampActivity, PatchClampExperiment, Trace, MultiChannelMultiTrialRecording, Distribution,
    QualifiedMultiTraceGeneration)
from fairgraph.base import KGQuery, as_list
from fairgraph.minds import Dataset

use_namespace('neuralactivity')
# Out:
# /Users/glynismattheisen/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
logging.basicConfig(filename="to_knowledge_graph.log",
                    filemode='a',
                    level=logging.DEBUG)

logger = logging.getLogger("nar")

token = ""
client = KGClient(token, nexus_endpoint='https://nexus-int.humanbrainproject.org/v0')

# direct paths dependent on environment
if 'int' in client.nexus_endpoint:
    Subject._path = '/core/subject/v0.1.2'
    Slice._path = '/core/slice/v0.1.0'
    PatchedCell._path = '/experiment/patchedcell/v0.1.0'
    Material._path = '/core/material/v0.1.2'
    Step._path = '/core/protocol/v0.1.6'
    Protocol._path = '/core/protocol/v0.1.6'
    ElectrophysiologicalStimulus._path = '/optophysiology/electrophysiologicalstimulus/v0.1.0'
    ElectrophysiologicalStimulation._path = '/optophysiology/electrophysiologicalstimulation/v0.5.0'
    Device._path = '/electrophysiology/device/v0.1.2'
    PatchClampExperiment._path = '/electrophysiology/stimulusexperiment/v0.3.1'
    QualifiedMultiTraceGeneration._path = '/electrophysiology/multitracegeneration/v0.2.3'
    MultiChannelMultiTrialRecording._path = '/electrophysiology/multitrace/v0.3.1'
    PatchedCellCollection._path = '/experiment/patchedcellcollection/v0.1.0'
    PatchedSlice._path = '/experiment/patchedslice/v0.1.0'
    PatchClampActivity._path = '/experiment/wholecellpatchclamp/v0.4.0'
    BrainSlicingActivity._path = '/experiment/brainslicing/v0.1.0'

# %% [markdown]
# ### Whole Cell Patch Clamp In Vivo
#
# #### Components
#
# Subject<br>
# PatchedCell<br>
# ElectrophysiologicalStimulus<br>
# ElectrophysiologicalStimulation<br>
# PatchClampExperiment<br>
# PatchClampActivity

# %% [markdown]
# # Locate Dataset and Define Contributors

# %%
dataset_name = None

minds_dataset = Dataset.by_name(dataset_name, client, resolved=True, api="query")

# map MINDSPerson to Person (for owner, contributors)
owner = [obj.resolve(client) for obj in as_list(minds_dataset.owners)]
contributors = [obj.resolve(client) for obj in as_list(minds_dataset.contributors)]
# Out:
# Warning: type information not available
# Warning: type information not available

# %%
for minds_person in contributors:
    print(minds_person)

# %%
"""People"""
abc = Person(given_name="", family_name="", email="")
abc.save(client)
deg = Person(given_name="", family_name="", email=None)
deg.save(client)
hij = Person(given_name="", family_name="", email=None)
hij.save(client)

people = [abc, deg, hij]

specimen_group = [obj.resolve(client) for obj in as_list(minds_dataset.specimen_group)]
minds_subjects = []
for sg in specimen_group:
    minds_subjects.extend([obj.resolve(client) for obj in as_list(sg.subjects)])

# %% [markdown]
# # Define Subjects, Samples, Experiment

# %%
for minds_subject in minds_subjects:
    print(minds_subject.name)
    print(minds_subject.samples)
    for minds_sample in as_list(minds_subject.samples):
        print(as_list(minds_subject.samples))
        minds_sample = minds_sample.resolve(client)
        print(minds_sample.name)
# Out:
# "with open(f'{minds_dataset.name}_trace_dict.yaml') as file:\n    trace_dict = yaml.load(file, Loader=yaml.FullLoader)\n    print(trace_dict)"

# %%
"""Import trace information from previous run if available"""

if os.path.exists(f'{minds_dataset.name}_trace_dict.yaml'):
    print("loading trace_dict")
    with open(f'{minds_dataset.name}_trace_dict.yaml') as file:
        trace_dict = yaml.load(file, Loader=yaml.FullLoader)
        preload = True
        print(trace_dict)
else:
    print("no saved trace_dict, building trace_dict")
    trace_dict = {}
    preload = False
# Out:
# hbp-00806.HBP_01
# hbp-00806.HBP_02
# hbp-00806.HBP_03
# hbp-00806.HBP_04
# hbp-00806.HBP_05
# hbp-00806.HBP_06
# hbp-00806.HBP_07
# hbp-00806.HBP_08
# hbp-00806.HBP_09
# hbp-00806.HBP_10
# hbp-00806.HBP_11
# hbp-00806.HBP_12
# hbp-00806.HBP_13
# hbp-00806.HBP_14
# hbp-00806.HBP_15
# hbp-00806.HBP_16
# hbp-00806.HBP_17
# hbp-00806.HBP_18
# hbp-00806.HBP_19
# hbp-00806.HBP_20
# hbp-00806.HBP_21
# hbp-00806.HBP_22
# hbp-00806.HBP_23
# hbp-00806.HBP_24
# hbp-00806.HBP_25
# hbp-00806.HBP_26
# hbp-00806.HBP_27
# hbp-00806.HBP_28

# %%
# map MINDSSubject to Subject
for minds_subject in minds_subjects:
    print(minds_subject.name)

    """Subject"""
    species = minds_subject.species.resolve(client).name
    strain = minds_subject.strains
    genotype = minds_subject.genotype
    sex = minds_subject.sex.resolve(client).name
    if sex == "Unknown" or sex == '<Unknown>':
        sex = None
    else:
        sex=Sex(sex)
    handedness = None
    age_units = "days"
    age_value = minds_subject.age
    if "-" in age_value:
        min, max = age_value.split("-")
        age_value = QuantitativeValueRange(int(min), int(max), age_units)
    else:
        age_value = QuantitativeValue(int(age_value), age_units)    
    age_category = "Post-natal"
    death_date = None # date type
    group = None # 'control group' v 'treatment group'

    subject = Subject(
      minds_subject.name,
      species=Species(species),
      strain=Strain(strain),
      genotype=Genotype(genotype),
      sex = sex,
      age=Age(age_value, age_category),
      death_date=None
      )
    print(subject)
    subject.save(client)
    assert subject.id is not None
            
    slices = []
    cells = []
    for minds_sample in as_list(minds_subject.samples):
        minds_sample = minds_sample.resolve(client)
        
        brain_regions = [BrainRegion("hippocampus CA1")]  
        
        patched_cell = PatchedCell(
            name = f"Patched cell in slice for {minds_sample.name}",
            brain_location = brain_regions,
            cell_type=CellType(""),
            morphology_type = MorphologyType(""),
            pipette_id = "", # string or int
            seal_resistance = QuantitativeValue(int(value), "units"),
            pipette_resistance = QuantitativeValue(int(value), "units"),
            liquid_junction_potential = QuantitativeValue(int(value), "units"),
            start_membrane_potential = QuantitativeValue(int(value), "units"),
            end_membrane_potential = QuantitativeValue(int(value), "units"),
            pipette_solution = "", 
            labeling_compound = "", 
            reversal_potential_cl = QuantitativeValue(int(value), "units"),
            description = ""
            )
        patched_cell.save(client)        
        cells.append(patched_cell)
        print(cells)

        cranial_window = CranialWindow(
            name = f"Cranial window for {subject.name}",
            brain_location = brain_location,
            window_type = "",
            diameter = QuantitativeValue(int(value), "units"),
            fluorescence_labeling = "",
            description = ""
        )
        cranial_window.save(client)
    
        craniotomy = Craniotomy(
            name = f"Craniotomy for {subject.name}",
            subject = subject,
            cranial_window = cranial_window,
            anesthesia = "",      
            protocol = Protocol(),
            start_time =, # datetime
            end_time = , # datetime
            people = people
        )
        craniotomy.save(client)

        step_one = Step(
            name = "Step one for protocol",
            previous_step_name = None,
            sequence_number = 1,
            version = "", # string or int
            identifier = "",
            distribution = Distribution(""),
            description = "",
            materials = Material(), # or list
            author = people 
        )
        step_one.save(client)
            
        step_two = Step(
            name = "Step two for protocol",
            previous_step_name = "Step one for protocl",
            sequence_number = 2,
            version = "", # string or int
            identifier = "",
            distribution = Distribution(""),
            description = "",
            materials - Material(), # or list
            author = people
        )
        step_two.save(client)

        steps = [step_one, step_two]
        
        protocol = Protocol(
            name = "Protcol for stimulation",
            version = "", # string or int
            identifier = "",
            distribution = Distribution(),
            number_of_steps = 1,
            steps = steps, 
            materials = Material(), # or list
            author = Person(), # or list
            date_published = # datetime
        )
        protocol.save(client)
    
        electrophysiological_stimulus = ElectrophysiologicalStimulus(
            name=f"Stimulus for patched cell in {minds_sample.name}",
            description = "",
            distribution = None
            )
        electrophysiological_stimulus.save(client)

        electrophysiological_stimulation = ElectrophysiologicalStimulation(
            name=f"Stimulation for patched cell in {minds_sample.name}",
            stimulus = electrophysiological_stimulus,
            protocol= protocol,
            citation = None,
            code = None,
            license = None
            )
        electrophysiological_stimulation.save(client)
        print(electrophysiological_stimulation)

        device = Device(
            name = "",
            manufacturer="",
            model_name="",
            software_version =None,
            serial_number = None,
            distribution = Distribution(""),
            )
        device.save(client)
        print(device)
        
        expt = PatchClampExperiment(
            name=f"Whole cell recordings in patched cell for {minds_sample.name}",
            recorded_cell= patched_cell,
            acquisition_device = device,
            stimulation = electrophysiological_stimulation,
            start_time = None,
            end_time = None,
            people = people,
            protocol=None
            )
        expt.save(client)
        print(expt)
        
        """Trace Generation"""
        """Accounts for muliple files existing per sample"""
        
        holding_potential_value = -70
        holding_potential_unit = 'mV'
        
        if preload: # building from YAML
            print("building trace metadata from YAML")
            trace_generation = QualifiedMultiTraceGeneration(
                f"Metadata for whole cell recordings in {minds_sample.name}",
                stimulus_experiment=expt,
                sweeps=trace_dict[minds_sample.name]['n_segments'],
                channel_type = None,
                holding_potential = QuantitativeValue(holding_potential_value, holding_potential_unit),
                sampling_frequency = None, 
                power_line_frequency = None
                )
            trace_generation.save(client)
            print(trace_generation)

            trace = MultiChannelMultiTrialRecording(
                f"Traces recorded in {minds_sample.name}",
                data_location=Distribution(location = trace_dict[minds_sample.name]['file_location'],
                  content_type="application/octet-stream"),
                generated_by=expt,
                generation_metadata=trace_generation,
                channel_names=trace_dict[minds_sample.name]['channel_names'],
                data_unit=trace_dict[minds_sample.name]['data_unit'],
                time_step=trace_dict[minds_sample.name]['time_step'],
                channel_type = None,
                part_of=minds_dataset
                )
            print(trace)
            trace.save(client)
        
        else:
            file_dir = "hbp-d00000/"
            filename = os.listdir(file_dir)
            file_url=file_dir + filename
            file_location = "https://object.cscs.ch/v1/AUTH_0000000000000000000/" + file_url

            io = RawBinarySignalIO(filename = file_url)
            data = io.read_block()
            n_segments = len(data.segments)
            sigs = data.segments[0].analogsignals
            channel_names = [sig.name for sig in sigs]
            units = [sig.units.dimensionality.string for sig in sigs]
            time_step = QuantitativeValue(**{
                                "unit_text": "ms",
                                "value": float(sigs[0].sampling_period.rescale("ms"))
                              })
            
            print("trace_dict does not exist, building trace dict") #
            trace_dict[minds_sample.name] = {}
            trace_dict[minds_sample.name]['channel_names'] = channel_names
            trace_dict[minds_sample.name]['data_unit'] = units
            trace_dict[minds_sample.name]['time_step'] = time_step
            trace_dict[minds_sample.name]['n_segments'] = n_segments
            trace_dict[minds_sample.name]['file_url'] = file_url
            trace_dict[minds_sample.name]['file_location'] = file_location

            trace_generation = QualifiedMultiTraceGeneration(
                f"Metadata for whole cell recordings in {minds_sample.name}",
                stimulus_experiment = expt,
                sweeps = n_segments,
                channel_type = None,
                holding_potential = QuantitativeValue(holding_potential_value, holding_potential_unit),
                sampling_frequency = None, 
                power_line_frequency = None
                )
            trace_generation.save(client)
            print(trace_generation)

            trace = MultiChannelMultiTrialRecording(
                f"Traces recorded in patched cell for {minds_sample.name}",
                data_location=Distribution(location = file_location,
                  content_type="application/octet-stream"),
                generated_by=expt,
                generation_metadata=trace_generation,
                channel_names=channel_names,
                data_unit=units,
                time_step=time_step,
                channel_type = None,
                part_of=minds_dataset
                )
            print(trace)
            trace.save(client)
                
    patch_clamp_activity = PatchClampActivity(
        name = f"Patch clamp activity for patched cell in {minds_subject.name}",
        recorded_tissue = slice,
        recorded_slice = patched_slice,
        protocol = None,
        people = people,
        start_time = None, # datetime format
        end_time = None # datetime format
        )
    patch_clamp_activity.save(client)
    print(patch_clamp_activity)
# Out:
# Subject(name='hbp-00806.HBP_01', species=Species('Mus musculus', 'http://purl.obolibrary.org/obo/NCBITaxon_10090'), strain=Strain('C57BL/6', 'https://dknet.org/data/record/nlx_154697-1/IMSR_JAX:000664/resolver?q=%2A&l=%2A&filter[]=Catalog%20Number:000664&i=5d4227790fbc3b6016f250e8'), genotype=Genotype('wild type', 'https://dknet.org/data/record/nlx_154697-1/MGI:5649737/resolver?q=wild%20type&l=wild%20type&i=5d4223a00fbc3b6016f04b3f'), sex=Sex('male', 'schema:Male'), age=Age(QuantitativeValue(60 'days'), 'Post-natal'), id=None)
# ElectrophysiologicalStimulation(name='Stimulation for hbp-00806.hbp_1.cell1', electrophysiological_stimulus=ElectrophysiologicalStimulus(name='Stimulus for hbp-00806.hbp_1.cell1', description='Whole cell current - clamp recordings were performed from the pyramidal layer of the hippocampal CA1 region using a Multiclamp 700B amplifier (Molecular Devices, USA). The data were digitized at 10 kHz using Spike2 software (CED UK) in conjunction with a Micro 1401 (CED UK). No bias current was injected during recordings and the membrane potential was not corrected for the liquid junction potential. Simultaneously, LFP was recorded from the pyramidal cell layer in the contralateral hippocampal CA1 region using a Multiclamp 700B amplifier.', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/optophysiology/electrophysiologicalstimulus/v0.1.0/cf987d6a-602b-4364-83e0-c380b9b1ed7d), protocol=Protocol(name='Whole cell current - clamp recordings', steps=Step(name='Whole cell current - clamp recordings', sequence_number=1, description='Whole cell current - clamp recordings were performed from the pyramidal layer of the hippocampal CA1 region using a Multiclamp 700B amplifier (Molecular Devices, USA). The data were digitized at 10 kHz using Spike2 software (CED UK) in conjunction with a Micro 1401 (CED UK). No bias current was injected during recordings and the membrane potential was not corrected for the liquid junction potential. Simultaneously, LFP was recorded from the pyramidal cell layer in the contralateral hippocampal CA1 region using a Multiclamp 700B amplifier.', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/step/v0.1.1/87294db5-69f2-49fb-9f00-75975deadc41), author=[Person(family_name='Jelitai', given_name='Marta', email='jelitai@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/ad280f5e-d866-4886-aee8-ab120fc56daa), Person(family_name='Komlosi', given_name='Ferenc', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/92ceae24-5c2d-4629-949d-82c8488b5312), Person(family_name='Kali', given_name='Szabolcs', email='kali@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/4c25a4e2-6742-4c1d-a625-7ef46b5768c4), Person(family_name='Freund', given_name='Tamas', email='freund@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/10d93c77-07bc-481c-a56f-43577fda73eb), Person(family_name='Varga', given_name='Viktor', email='varga.viktor@koki.mta.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/f8fb24b1-4d86-4965-9368-f2a5896e5f0f)], id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/protocol/v0.1.6/d296aac3-ba95-48fa-bea6-bdde0f34d176), id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/optophysiology/electrophysiologicalstimulation/v0.1.0/04c1709d-402a-40f7-99c4-009cea95bf8e)
# sample hbp-00806.HBP_1.cell1
# file_dir Freund_SGA1_T1.2.5/HC-awake-ephys/HBP_1/cell1/ephys/
# filename Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_1_cell1_ephys__160712_cell1.txt
# file_url Freund_SGA1_T1.2.5/HC-awake-ephys/HBP_1/cell1/ephys/Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_1_cell1_ephys__160712_cell1.txt
# file_location https://object.cscs.ch/v1/AUTH_63ea6845b1d34ad7a43c8158d9572867/Freund_SGA1_T1.2.5/HC-awake-ephys/HBP_1/cell1/ephys/Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_1_cell1_ephys__160712_cell1.txt
# Second .txt
# QualifiedMultiTraceGeneration(name='Metadata for whole cell recordings in hbp-00806.HBP_1.cell1', stimulus_experiment=PatchClampExperiment(name='Whole cell recordings in hbp-00806.hbp_1.cell1', recorded_cell=PatchedCell(name='hbp-00806.HBP_1.cell1', brain_location=[BrainRegion('hippocampus CA1', 'http://uri.interlex.org/ilx_0101520')], cell_type=CellType('hippocampus CA1 pyramidal cell', 'http://uri.interlex.org/ilx_0105031'), id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/experiment/patchedcell/v0.1.0/392d5e00-50f7-4aa7-a657-e94b6b45d96f), acquisition_device=Device(name='Multiclamp 700B amplifier', manufacturer='Molecular Devices', model_name='700B', distribution=Distribution('https://www.moleculardevices.com/sites/default/files/en/assets/data-sheets/dd/cns/multiclamp-700b-microelectrode-amplifier.pdf'), id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/electrophysiology/device/v0.1.2/2a4b755d-1e34-4e33-b6bc-e823206c5214), stimulation=ElectrophysiologicalStimulation(name='Stimulation for hbp-00806.hbp_1.cell1', electrophysiological_stimulus=ElectrophysiologicalStimulus(name='Stimulus for hbp-00806.hbp_1.cell1', description='Whole cell current - clamp recordings were performed from the pyramidal layer of the hippocampal CA1 region using a Multiclamp 700B amplifier (Molecular Devices, USA). The data were digitized at 10 kHz using Spike2 software (CED UK) in conjunction with a Micro 1401 (CED UK). No bias current was injected during recordings and the membrane potential was not corrected for the liquid junction potential. Simultaneously, LFP was recorded from the pyramidal cell layer in the contralateral hippocampal CA1 region using a Multiclamp 700B amplifier.', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/optophysiology/electrophysiologicalstimulus/v0.1.0/cf987d6a-602b-4364-83e0-c380b9b1ed7d), protocol=Protocol(name='Whole cell current - clamp recordings', steps=Step(name='Whole cell current - clamp recordings', sequence_number=1, description='Whole cell current - clamp recordings were performed from the pyramidal layer of the hippocampal CA1 region using a Multiclamp 700B amplifier (Molecular Devices, USA). The data were digitized at 10 kHz using Spike2 software (CED UK) in conjunction with a Micro 1401 (CED UK). No bias current was injected during recordings and the membrane potential was not corrected for the liquid junction potential. Simultaneously, LFP was recorded from the pyramidal cell layer in the contralateral hippocampal CA1 region using a Multiclamp 700B amplifier.', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/step/v0.1.1/87294db5-69f2-49fb-9f00-75975deadc41), author=[Person(family_name='Jelitai', given_name='Marta', email='jelitai@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/ad280f5e-d866-4886-aee8-ab120fc56daa), Person(family_name='Komlosi', given_name='Ferenc', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/92ceae24-5c2d-4629-949d-82c8488b5312), Person(family_name='Kali', given_name='Szabolcs', email='kali@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/4c25a4e2-6742-4c1d-a625-7ef46b5768c4), Person(family_name='Freund', given_name='Tamas', email='freund@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/10d93c77-07bc-481c-a56f-43577fda73eb), Person(family_name='Varga', given_name='Viktor', email='varga.viktor@koki.mta.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/f8fb24b1-4d86-4965-9368-f2a5896e5f0f)], id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/protocol/v0.1.6/d296aac3-ba95-48fa-bea6-bdde0f34d176), id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/optophysiology/electrophysiologicalstimulation/v0.1.0/04c1709d-402a-40f7-99c4-009cea95bf8e), id=https://nexus-int.humanbra ...
# filename Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_1_cell1_ephys__160712_cell1.mat
# file_url Freund_SGA1_T1.2.5/HC-awake-ephys/HBP_1/cell1/ephys/Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_1_cell1_ephys__160712_cell1.mat
# file_location https://object.cscs.ch/v1/AUTH_63ea6845b1d34ad7a43c8158d9572867/Freund_SGA1_T1.2.5/HC-awake-ephys/HBP_1/cell1/ephys/Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_1_cell1_ephys__160712_cell1.mat
# first .mat
# QualifiedMultiTraceGeneration(name='Metadata for whole cell recordings in hbp-00806.HBP_1.cell1', stimulus_experiment=PatchClampExperiment(name='Whole cell recordings in hbp-00806.hbp_1.cell1', recorded_cell=PatchedCell(name='hbp-00806.HBP_1.cell1', brain_location=[BrainRegion('hippocampus CA1', 'http://uri.interlex.org/ilx_0101520')], cell_type=CellType('hippocampus CA1 pyramidal cell', 'http://uri.interlex.org/ilx_0105031'), id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/experiment/patchedcell/v0.1.0/392d5e00-50f7-4aa7-a657-e94b6b45d96f), acquisition_device=Device(name='Multiclamp 700B amplifier', manufacturer='Molecular Devices', model_name='700B', distribution=Distribution('https://www.moleculardevices.com/sites/default/files/en/assets/data-sheets/dd/cns/multiclamp-700b-microelectrode-amplifier.pdf'), id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/electrophysiology/device/v0.1.2/2a4b755d-1e34-4e33-b6bc-e823206c5214), stimulation=ElectrophysiologicalStimulation(name='Stimulation for hbp-00806.hbp_1.cell1', electrophysiological_stimulus=ElectrophysiologicalStimulus(name='Stimulus for hbp-00806.hbp_1.cell1', description='Whole cell current - clamp recordings were performed from the pyramidal layer of the hippocampal CA1 region using a Multiclamp 700B amplifier (Molecular Devices, USA). The data were digitized at 10 kHz using Spike2 software (CED UK) in conjunction with a Micro 1401 (CED UK). No bias current was injected during recordings and the membrane potential was not corrected for the liquid junction potential. Simultaneously, LFP was recorded from the pyramidal cell layer in the contralateral hippocampal CA1 region using a Multiclamp 700B amplifier.', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/optophysiology/electrophysiologicalstimulus/v0.1.0/cf987d6a-602b-4364-83e0-c380b9b1ed7d), protocol=Protocol(name='Whole cell current - clamp recordings', steps=Step(name='Whole cell current - clamp recordings', sequence_number=1, description='Whole cell current - clamp recordings were performed from the pyramidal layer of the hippocampal CA1 region using a Multiclamp 700B amplifier (Molecular Devices, USA). The data were digitized at 10 kHz using Spike2 software (CED UK) in conjunction with a Micro 1401 (CED UK). No bias current was injected during recordings and the membrane potential was not corrected for the liquid junction potential. Simultaneously, LFP was recorded from the pyramidal cell layer in the contralateral hippocampal CA1 region using a Multiclamp 700B amplifier.', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/step/v0.1.1/87294db5-69f2-49fb-9f00-75975deadc41), author=[Person(family_name='Jelitai', given_name='Marta', email='jelitai@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/ad280f5e-d866-4886-aee8-ab120fc56daa), Person(family_name='Komlosi', given_name='Ferenc', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/92ceae24-5c2d-4629-949d-82c8488b5312), Person(family_name='Kali', given_name='Szabolcs', email='kali@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/4c25a4e2-6742-4c1d-a625-7ef46b5768c4), Person(family_name='Freund', given_name='Tamas', email='freund@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/10d93c77-07bc-481c-a56f-43577fda73eb), Person(family_name='Varga', given_name='Viktor', email='varga.viktor@koki.mta.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/f8fb24b1-4d86-4965-9368-f2a5896e5f0f)], id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/protocol/v0.1.6/d296aac3-ba95-48fa-bea6-bdde0f34d176), id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/optophysiology/electrophysiologicalstimulation/v0.1.0/04c1709d-402a-40f7-99c4-009cea95bf8e), id=https://nexus-int.humanbra ...
# Subject(name='hbp-00806.HBP_02', species=Species('Mus musculus', 'http://purl.obolibrary.org/obo/NCBITaxon_10090'), strain=Strain('C57BL/6', 'https://dknet.org/data/record/nlx_154697-1/IMSR_JAX:000664/resolver?q=%2A&l=%2A&filter[]=Catalog%20Number:000664&i=5d4227790fbc3b6016f250e8'), genotype=Genotype('wild type', 'https://dknet.org/data/record/nlx_154697-1/MGI:5649737/resolver?q=wild%20type&l=wild%20type&i=5d4223a00fbc3b6016f04b3f'), sex=Sex('male', 'schema:Male'), age=Age(QuantitativeValue(73 'days'), 'Post-natal'), id=None)
# ElectrophysiologicalStimulation(name='Stimulation for hbp-00806.hbp_2.cell1', electrophysiological_stimulus=ElectrophysiologicalStimulus(name='Stimulus for hbp-00806.hbp_2.cell1', description='Whole cell current - clamp recordings were performed from the pyramidal layer of the hippocampal CA1 region using a Multiclamp 700B amplifier (Molecular Devices, USA). The data were digitized at 10 kHz using Spike2 software (CED UK) in conjunction with a Micro 1401 (CED UK). No bias current was injected during recordings and the membrane potential was not corrected for the liquid junction potential. Simultaneously, LFP was recorded from the pyramidal cell layer in the contralateral hippocampal CA1 region using a Multiclamp 700B amplifier.', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/optophysiology/electrophysiologicalstimulus/v0.1.0/03da53c5-ea1f-4cb2-aba6-84ebbd7d9dfe), protocol=Protocol(name='Whole cell current - clamp recordings', steps=Step(name='Whole cell current - clamp recordings', sequence_number=1, description='Whole cell current - clamp recordings were performed from the pyramidal layer of the hippocampal CA1 region using a Multiclamp 700B amplifier (Molecular Devices, USA). The data were digitized at 10 kHz using Spike2 software (CED UK) in conjunction with a Micro 1401 (CED UK). No bias current was injected during recordings and the membrane potential was not corrected for the liquid junction potential. Simultaneously, LFP was recorded from the pyramidal cell layer in the contralateral hippocampal CA1 region using a Multiclamp 700B amplifier.', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/step/v0.1.1/87294db5-69f2-49fb-9f00-75975deadc41), author=[Person(family_name='Jelitai', given_name='Marta', email='jelitai@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/ad280f5e-d866-4886-aee8-ab120fc56daa), Person(family_name='Komlosi', given_name='Ferenc', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/92ceae24-5c2d-4629-949d-82c8488b5312), Person(family_name='Kali', given_name='Szabolcs', email='kali@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/4c25a4e2-6742-4c1d-a625-7ef46b5768c4), Person(family_name='Freund', given_name='Tamas', email='freund@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/10d93c77-07bc-481c-a56f-43577fda73eb), Person(family_name='Varga', given_name='Viktor', email='varga.viktor@koki.mta.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/f8fb24b1-4d86-4965-9368-f2a5896e5f0f)], id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/protocol/v0.1.6/d296aac3-ba95-48fa-bea6-bdde0f34d176), id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/optophysiology/electrophysiologicalstimulation/v0.1.0/4a72ac55-401c-4d03-85fb-642e29d7af91)
# sample hbp-00806.HBP_2.cell1
# file_dir Freund_SGA1_T1.2.5/HC-awake-ephys/HBP_2/cell1/ephys/
# filename Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_2_cell1_ephys__160713_cell1.mat
# file_url Freund_SGA1_T1.2.5/HC-awake-ephys/HBP_2/cell1/ephys/Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_2_cell1_ephys__160713_cell1.mat
# file_location https://object.cscs.ch/v1/AUTH_63ea6845b1d34ad7a43c8158d9572867/Freund_SGA1_T1.2.5/HC-awake-ephys/HBP_2/cell1/ephys/Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_2_cell1_ephys__160713_cell1.mat
# first .mat
# QualifiedMultiTraceGeneration(name='Metadata for whole cell recordings in hbp-00806.HBP_2.cell1', stimulus_experiment=PatchClampExperiment(name='Whole cell recordings in hbp-00806.hbp_2.cell1', recorded_cell=PatchedCell(name='hbp-00806.HBP_2.cell1', brain_location=[BrainRegion('hippocampus CA1', 'http://uri.interlex.org/ilx_0101520')], cell_type=CellType('hippocampus CA1 pyramidal cell', 'http://uri.interlex.org/ilx_0105031'), id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/experiment/patchedcell/v0.1.0/7460c840-0f15-4b7b-8b80-4e4457861fc2), acquisition_device=Device(name='Multiclamp 700B amplifier', manufacturer='Molecular Devices', model_name='700B', distribution=Distribution('https://www.moleculardevices.com/sites/default/files/en/assets/data-sheets/dd/cns/multiclamp-700b-microelectrode-amplifier.pdf'), id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/electrophysiology/device/v0.1.2/2a4b755d-1e34-4e33-b6bc-e823206c5214), stimulation=ElectrophysiologicalStimulation(name='Stimulation for hbp-00806.hbp_2.cell1', electrophysiological_stimulus=ElectrophysiologicalStimulus(name='Stimulus for hbp-00806.hbp_2.cell1', description='Whole cell current - clamp recordings were performed from the pyramidal layer of the hippocampal CA1 region using a Multiclamp 700B amplifier (Molecular Devices, USA). The data were digitized at 10 kHz using Spike2 software (CED UK) in conjunction with a Micro 1401 (CED UK). No bias current was injected during recordings and the membrane potential was not corrected for the liquid junction potential. Simultaneously, LFP was recorded from the pyramidal cell layer in the contralateral hippocampal CA1 region using a Multiclamp 700B amplifier.', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/optophysiology/electrophysiologicalstimulus/v0.1.0/03da53c5-ea1f-4cb2-aba6-84ebbd7d9dfe), protocol=Protocol(name='Whole cell current - clamp recordings', steps=Step(name='Whole cell current - clamp recordings', sequence_number=1, description='Whole cell current - clamp recordings were performed from the pyramidal layer of the hippocampal CA1 region using a Multiclamp 700B amplifier (Molecular Devices, USA). The data were digitized at 10 kHz using Spike2 software (CED UK) in conjunction with a Micro 1401 (CED UK). No bias current was injected during recordings and the membrane potential was not corrected for the liquid junction potential. Simultaneously, LFP was recorded from the pyramidal cell layer in the contralateral hippocampal CA1 region using a Multiclamp 700B amplifier.', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/step/v0.1.1/87294db5-69f2-49fb-9f00-75975deadc41), author=[Person(family_name='Jelitai', given_name='Marta', email='jelitai@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/ad280f5e-d866-4886-aee8-ab120fc56daa), Person(family_name='Komlosi', given_name='Ferenc', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/92ceae24-5c2d-4629-949d-82c8488b5312), Person(family_name='Kali', given_name='Szabolcs', email='kali@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/4c25a4e2-6742-4c1d-a625-7ef46b5768c4), Person(family_name='Freund', given_name='Tamas', email='freund@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/10d93c77-07bc-481c-a56f-43577fda73eb), Person(family_name='Varga', given_name='Viktor', email='varga.viktor@koki.mta.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/f8fb24b1-4d86-4965-9368-f2a5896e5f0f)], id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/protocol/v0.1.6/d296aac3-ba95-48fa-bea6-bdde0f34d176), id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/optophysiology/electrophysiologicalstimulation/v0.1.0/4a72ac55-401c-4d03-85fb-642e29d7af91), id=https://nexus-int.humanbra ...
# filename Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_2_cell1_ephys__160713_cell1.txt
# file_url Freund_SGA1_T1.2.5/HC-awake-ephys/HBP_2/cell1/ephys/Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_2_cell1_ephys__160713_cell1.txt
# file_location https://object.cscs.ch/v1/AUTH_63ea6845b1d34ad7a43c8158d9572867/Freund_SGA1_T1.2.5/HC-awake-ephys/HBP_2/cell1/ephys/Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_2_cell1_ephys__160713_cell1.txt
# Second .txt
# QualifiedMultiTraceGeneration(name='Metadata for whole cell recordings in hbp-00806.HBP_2.cell1', stimulus_experiment=PatchClampExperiment(name='Whole cell recordings in hbp-00806.hbp_2.cell1', recorded_cell=PatchedCell(name='hbp-00806.HBP_2.cell1', brain_location=[BrainRegion('hippocampus CA1', 'http://uri.interlex.org/ilx_0101520')], cell_type=CellType('hippocampus CA1 pyramidal cell', 'http://uri.interlex.org/ilx_0105031'), id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/experiment/patchedcell/v0.1.0/7460c840-0f15-4b7b-8b80-4e4457861fc2), acquisition_device=Device(name='Multiclamp 700B amplifier', manufacturer='Molecular Devices', model_name='700B', distribution=Distribution('https://www.moleculardevices.com/sites/default/files/en/assets/data-sheets/dd/cns/multiclamp-700b-microelectrode-amplifier.pdf'), id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/electrophysiology/device/v0.1.2/2a4b755d-1e34-4e33-b6bc-e823206c5214), stimulation=ElectrophysiologicalStimulation(name='Stimulation for hbp-00806.hbp_2.cell1', electrophysiological_stimulus=ElectrophysiologicalStimulus(name='Stimulus for hbp-00806.hbp_2.cell1', description='Whole cell current - clamp recordings were performed from the pyramidal layer of the hippocampal CA1 region using a Multiclamp 700B amplifier (Molecular Devices, USA). The data were digitized at 10 kHz using Spike2 software (CED UK) in conjunction with a Micro 1401 (CED UK). No bias current was injected during recordings and the membrane potential was not corrected for the liquid junction potential. Simultaneously, LFP was recorded from the pyramidal cell layer in the contralateral hippocampal CA1 region using a Multiclamp 700B amplifier.', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/optophysiology/electrophysiologicalstimulus/v0.1.0/03da53c5-ea1f-4cb2-aba6-84ebbd7d9dfe), protocol=Protocol(name='Whole cell current - clamp recordings', steps=Step(name='Whole cell current - clamp recordings', sequence_number=1, description='Whole cell current - clamp recordings were performed from the pyramidal layer of the hippocampal CA1 region using a Multiclamp 700B amplifier (Molecular Devices, USA). The data were digitized at 10 kHz using Spike2 software (CED UK) in conjunction with a Micro 1401 (CED UK). No bias current was injected during recordings and the membrane potential was not corrected for the liquid junction potential. Simultaneously, LFP was recorded from the pyramidal cell layer in the contralateral hippocampal CA1 region using a Multiclamp 700B amplifier.', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/step/v0.1.1/87294db5-69f2-49fb-9f00-75975deadc41), author=[Person(family_name='Jelitai', given_name='Marta', email='jelitai@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/ad280f5e-d866-4886-aee8-ab120fc56daa), Person(family_name='Komlosi', given_name='Ferenc', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/92ceae24-5c2d-4629-949d-82c8488b5312), Person(family_name='Kali', given_name='Szabolcs', email='kali@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/4c25a4e2-6742-4c1d-a625-7ef46b5768c4), Person(family_name='Freund', given_name='Tamas', email='freund@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/10d93c77-07bc-481c-a56f-43577fda73eb), Person(family_name='Varga', given_name='Viktor', email='varga.viktor@koki.mta.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/f8fb24b1-4d86-4965-9368-f2a5896e5f0f)], id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/protocol/v0.1.6/d296aac3-ba95-48fa-bea6-bdde0f34d176), id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/optophysiology/electrophysiologicalstimulation/v0.1.0/4a72ac55-401c-4d03-85fb-642e29d7af91), id=https://nexus-int.humanbra ...
# ElectrophysiologicalStimulation(name='Stimulation for hbp-00806.hbp_2.cell2', electrophysiological_stimulus=ElectrophysiologicalStimulus(name='Stimulus for hbp-00806.hbp_2.cell2', description='Whole cell current - clamp recordings were performed from the pyramidal layer of the hippocampal CA1 region using a Multiclamp 700B amplifier (Molecular Devices, USA). The data were digitized at 10 kHz using Spike2 software (CED UK) in conjunction with a Micro 1401 (CED UK). No bias current was injected during recordings and the membrane potential was not corrected for the liquid junction potential. Simultaneously, LFP was recorded from the pyramidal cell layer in the contralateral hippocampal CA1 region using a Multiclamp 700B amplifier.', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/optophysiology/electrophysiologicalstimulus/v0.1.0/338cb2dd-298f-42d7-b7ec-939897540af0), protocol=Protocol(name='Whole cell current - clamp recordings', steps=Step(name='Whole cell current - clamp recordings', sequence_number=1, description='Whole cell current - clamp recordings were performed from the pyramidal layer of the hippocampal CA1 region using a Multiclamp 700B amplifier (Molecular Devices, USA). The data were digitized at 10 kHz using Spike2 software (CED UK) in conjunction with a Micro 1401 (CED UK). No bias current was injected during recordings and the membrane potential was not corrected for the liquid junction potential. Simultaneously, LFP was recorded from the pyramidal cell layer in the contralateral hippocampal CA1 region using a Multiclamp 700B amplifier.', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/step/v0.1.1/87294db5-69f2-49fb-9f00-75975deadc41), author=[Person(family_name='Jelitai', given_name='Marta', email='jelitai@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/ad280f5e-d866-4886-aee8-ab120fc56daa), Person(family_name='Komlosi', given_name='Ferenc', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/92ceae24-5c2d-4629-949d-82c8488b5312), Person(family_name='Kali', given_name='Szabolcs', email='kali@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/4c25a4e2-6742-4c1d-a625-7ef46b5768c4), Person(family_name='Freund', given_name='Tamas', email='freund@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/10d93c77-07bc-481c-a56f-43577fda73eb), Person(family_name='Varga', given_name='Viktor', email='varga.viktor@koki.mta.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/f8fb24b1-4d86-4965-9368-f2a5896e5f0f)], id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/protocol/v0.1.6/d296aac3-ba95-48fa-bea6-bdde0f34d176), id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/optophysiology/electrophysiologicalstimulation/v0.1.0/4c971e21-8167-4195-b468-68c4726d65d2)
# sample hbp-00806.HBP_2.cell2
# file_dir Freund_SGA1_T1.2.5/HC-awake-ephys/HBP_2/cell2/ephys/
# filename Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_2_cell2_ephys__160713_cell2.txt
# file_url Freund_SGA1_T1.2.5/HC-awake-ephys/HBP_2/cell2/ephys/Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_2_cell2_ephys__160713_cell2.txt
# file_location https://object.cscs.ch/v1/AUTH_63ea6845b1d34ad7a43c8158d9572867/Freund_SGA1_T1.2.5/HC-awake-ephys/HBP_2/cell2/ephys/Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_2_cell2_ephys__160713_cell2.txt
# Second .txt
# QualifiedMultiTraceGeneration(name='Metadata for whole cell recordings in hbp-00806.HBP_2.cell2', stimulus_experiment=PatchClampExperiment(name='Whole cell recordings in hbp-00806.hbp_2.cell2', recorded_cell=PatchedCell(name='hbp-00806.HBP_2.cell2', brain_location=[BrainRegion('hippocampus CA1', 'http://uri.interlex.org/ilx_0101520')], cell_type=CellType('hippocampus CA1 pyramidal cell', 'http://uri.interlex.org/ilx_0105031'), id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/experiment/patchedcell/v0.1.0/9ddef5b5-0692-4b8c-acb1-78f1872f1ccf), acquisition_device=Device(name='Multiclamp 700B amplifier', manufacturer='Molecular Devices', model_name='700B', distribution=Distribution('https://www.moleculardevices.com/sites/default/files/en/assets/data-sheets/dd/cns/multiclamp-700b-microelectrode-amplifier.pdf'), id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/electrophysiology/device/v0.1.2/2a4b755d-1e34-4e33-b6bc-e823206c5214), stimulation=ElectrophysiologicalStimulation(name='Stimulation for hbp-00806.hbp_2.cell2', electrophysiological_stimulus=ElectrophysiologicalStimulus(name='Stimulus for hbp-00806.hbp_2.cell2', description='Whole cell current - clamp recordings were performed from the pyramidal layer of the hippocampal CA1 region using a Multiclamp 700B amplifier (Molecular Devices, USA). The data were digitized at 10 kHz using Spike2 software (CED UK) in conjunction with a Micro 1401 (CED UK). No bias current was injected during recordings and the membrane potential was not corrected for the liquid junction potential. Simultaneously, LFP was recorded from the pyramidal cell layer in the contralateral hippocampal CA1 region using a Multiclamp 700B amplifier.', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/optophysiology/electrophysiologicalstimulus/v0.1.0/338cb2dd-298f-42d7-b7ec-939897540af0), protocol=Protocol(name='Whole cell current - clamp recordings', steps=Step(name='Whole cell current - clamp recordings', sequence_number=1, description='Whole cell current - clamp recordings were performed from the pyramidal layer of the hippocampal CA1 region using a Multiclamp 700B amplifier (Molecular Devices, USA). The data were digitized at 10 kHz using Spike2 software (CED UK) in conjunction with a Micro 1401 (CED UK). No bias current was injected during recordings and the membrane potential was not corrected for the liquid junction potential. Simultaneously, LFP was recorded from the pyramidal cell layer in the contralateral hippocampal CA1 region using a Multiclamp 700B amplifier.', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/step/v0.1.1/87294db5-69f2-49fb-9f00-75975deadc41), author=[Person(family_name='Jelitai', given_name='Marta', email='jelitai@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/ad280f5e-d866-4886-aee8-ab120fc56daa), Person(family_name='Komlosi', given_name='Ferenc', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/92ceae24-5c2d-4629-949d-82c8488b5312), Person(family_name='Kali', given_name='Szabolcs', email='kali@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/4c25a4e2-6742-4c1d-a625-7ef46b5768c4), Person(family_name='Freund', given_name='Tamas', email='freund@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/10d93c77-07bc-481c-a56f-43577fda73eb), Person(family_name='Varga', given_name='Viktor', email='varga.viktor@koki.mta.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/f8fb24b1-4d86-4965-9368-f2a5896e5f0f)], id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/protocol/v0.1.6/d296aac3-ba95-48fa-bea6-bdde0f34d176), id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/optophysiology/electrophysiologicalstimulation/v0.1.0/4c971e21-8167-4195-b468-68c4726d65d2), id=https://nexus-int.humanbra ...
# filename Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_2_cell2_ephys__160713_cell2.mat
# file_url Freund_SGA1_T1.2.5/HC-awake-ephys/HBP_2/cell2/ephys/Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_2_cell2_ephys__160713_cell2.mat
# file_location https://object.cscs.ch/v1/AUTH_63ea6845b1d34ad7a43c8158d9572867/Freund_SGA1_T1.2.5/HC-awake-ephys/HBP_2/cell2/ephys/Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_2_cell2_ephys__160713_cell2.mat
# first .mat
# QualifiedMultiTraceGeneration(name='Metadata for whole cell recordings in hbp-00806.HBP_2.cell2', stimulus_experiment=PatchClampExperiment(name='Whole cell recordings in hbp-00806.hbp_2.cell2', recorded_cell=PatchedCell(name='hbp-00806.HBP_2.cell2', brain_location=[BrainRegion('hippocampus CA1', 'http://uri.interlex.org/ilx_0101520')], cell_type=CellType('hippocampus CA1 pyramidal cell', 'http://uri.interlex.org/ilx_0105031'), id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/experiment/patchedcell/v0.1.0/9ddef5b5-0692-4b8c-acb1-78f1872f1ccf), acquisition_device=Device(name='Multiclamp 700B amplifier', manufacturer='Molecular Devices', model_name='700B', distribution=Distribution('https://www.moleculardevices.com/sites/default/files/en/assets/data-sheets/dd/cns/multiclamp-700b-microelectrode-amplifier.pdf'), id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/electrophysiology/device/v0.1.2/2a4b755d-1e34-4e33-b6bc-e823206c5214), stimulation=ElectrophysiologicalStimulation(name='Stimulation for hbp-00806.hbp_2.cell2', electrophysiological_stimulus=ElectrophysiologicalStimulus(name='Stimulus for hbp-00806.hbp_2.cell2', description='Whole cell current - clamp recordings were performed from the pyramidal layer of the hippocampal CA1 region using a Multiclamp 700B amplifier (Molecular Devices, USA). The data were digitized at 10 kHz using Spike2 software (CED UK) in conjunction with a Micro 1401 (CED UK). No bias current was injected during recordings and the membrane potential was not corrected for the liquid junction potential. Simultaneously, LFP was recorded from the pyramidal cell layer in the contralateral hippocampal CA1 region using a Multiclamp 700B amplifier.', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/optophysiology/electrophysiologicalstimulus/v0.1.0/338cb2dd-298f-42d7-b7ec-939897540af0), protocol=Protocol(name='Whole cell current - clamp recordings', steps=Step(name='Whole cell current - clamp recordings', sequence_number=1, description='Whole cell current - clamp recordings were performed from the pyramidal layer of the hippocampal CA1 region using a Multiclamp 700B amplifier (Molecular Devices, USA). The data were digitized at 10 kHz using Spike2 software (CED UK) in conjunction with a Micro 1401 (CED UK). No bias current was injected during recordings and the membrane potential was not corrected for the liquid junction potential. Simultaneously, LFP was recorded from the pyramidal cell layer in the contralateral hippocampal CA1 region using a Multiclamp 700B amplifier.', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/step/v0.1.1/87294db5-69f2-49fb-9f00-75975deadc41), author=[Person(family_name='Jelitai', given_name='Marta', email='jelitai@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/ad280f5e-d866-4886-aee8-ab120fc56daa), Person(family_name='Komlosi', given_name='Ferenc', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/92ceae24-5c2d-4629-949d-82c8488b5312), Person(family_name='Kali', given_name='Szabolcs', email='kali@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/4c25a4e2-6742-4c1d-a625-7ef46b5768c4), Person(family_name='Freund', given_name='Tamas', email='freund@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/10d93c77-07bc-481c-a56f-43577fda73eb), Person(family_name='Varga', given_name='Viktor', email='varga.viktor@koki.mta.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/f8fb24b1-4d86-4965-9368-f2a5896e5f0f)], id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/protocol/v0.1.6/d296aac3-ba95-48fa-bea6-bdde0f34d176), id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/optophysiology/electrophysiologicalstimulation/v0.1.0/4c971e21-8167-4195-b468-68c4726d65d2), id=https://nexus-int.humanbra ...
# Subject(name='hbp-00806.HBP_03', species=Species('Mus musculus', 'http://purl.obolibrary.org/obo/NCBITaxon_10090'), strain=Strain('C57BL/6', 'https://dknet.org/data/record/nlx_154697-1/IMSR_JAX:000664/resolver?q=%2A&l=%2A&filter[]=Catalog%20Number:000664&i=5d4227790fbc3b6016f250e8'), genotype=Genotype('wild type', 'https://dknet.org/data/record/nlx_154697-1/MGI:5649737/resolver?q=wild%20type&l=wild%20type&i=5d4223a00fbc3b6016f04b3f'), sex=Sex('male', 'schema:Male'), age=Age(QuantitativeValue(82 'days'), 'Post-natal'), id=None)
# ElectrophysiologicalStimulation(name='Stimulation for hbp-00806.hbp_3.cell1', electrophysiological_stimulus=ElectrophysiologicalStimulus(name='Stimulus for hbp-00806.hbp_3.cell1', description='Whole cell current - clamp recordings were performed from the pyramidal layer of the hippocampal CA1 region using a Multiclamp 700B amplifier (Molecular Devices, USA). The data were digitized at 10 kHz using Spike2 software (CED UK) in conjunction with a Micro 1401 (CED UK). No bias current was injected during recordings and the membrane potential was not corrected for the liquid junction potential. Simultaneously, LFP was recorded from the pyramidal cell layer in the contralateral hippocampal CA1 region using a Multiclamp 700B amplifier.', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/optophysiology/electrophysiologicalstimulus/v0.1.0/44379a58-3ad5-4a47-8cb4-9d80764e5409), protocol=Protocol(name='Whole cell current - clamp recordings', steps=Step(name='Whole cell current - clamp recordings', sequence_number=1, description='Whole cell current - clamp recordings were performed from the pyramidal layer of the hippocampal CA1 region using a Multiclamp 700B amplifier (Molecular Devices, USA). The data were digitized at 10 kHz using Spike2 software (CED UK) in conjunction with a Micro 1401 (CED UK). No bias current was injected during recordings and the membrane potential was not corrected for the liquid junction potential. Simultaneously, LFP was recorded from the pyramidal cell layer in the contralateral hippocampal CA1 region using a Multiclamp 700B amplifier.', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/step/v0.1.1/87294db5-69f2-49fb-9f00-75975deadc41), author=[Person(family_name='Jelitai', given_name='Marta', email='jelitai@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/ad280f5e-d866-4886-aee8-ab120fc56daa), Person(family_name='Komlosi', given_name='Ferenc', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/92ceae24-5c2d-4629-949d-82c8488b5312), Person(family_name='Kali', given_name='Szabolcs', email='kali@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/4c25a4e2-6742-4c1d-a625-7ef46b5768c4), Person(family_name='Freund', given_name='Tamas', email='freund@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/10d93c77-07bc-481c-a56f-43577fda73eb), Person(family_name='Varga', given_name='Viktor', email='varga.viktor@koki.mta.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/f8fb24b1-4d86-4965-9368-f2a5896e5f0f)], id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/protocol/v0.1.6/d296aac3-ba95-48fa-bea6-bdde0f34d176), id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/optophysiology/electrophysiologicalstimulation/v0.1.0/bbedef4c-6bda-40ea-a4ee-29329b5e1025)
# sample hbp-00806.HBP_3.cell1
# file_dir Freund_SGA1_T1.2.5/HC-awake-ephys/HBP_3/cell1/ephys/
# filename Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_3_cell1_ephys__160722_cell1.txt
# file_url Freund_SGA1_T1.2.5/HC-awake-ephys/HBP_3/cell1/ephys/Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_3_cell1_ephys__160722_cell1.txt
# file_location https://object.cscs.ch/v1/AUTH_63ea6845b1d34ad7a43c8158d9572867/Freund_SGA1_T1.2.5/HC-awake-ephys/HBP_3/cell1/ephys/Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_3_cell1_ephys__160722_cell1.txt
# Second .txt
# QualifiedMultiTraceGeneration(name='Metadata for whole cell recordings in hbp-00806.HBP_3.cell1', stimulus_experiment=PatchClampExperiment(name='Whole cell recordings in hbp-00806.hbp_3.cell1', recorded_cell=PatchedCell(name='hbp-00806.HBP_3.cell1', brain_location=[BrainRegion('hippocampus CA1', 'http://uri.interlex.org/ilx_0101520')], cell_type=CellType('hippocampus CA1 pyramidal cell', 'http://uri.interlex.org/ilx_0105031'), id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/experiment/patchedcell/v0.1.0/bbbb7782-17bd-4a08-b892-c577279e1b22), acquisition_device=Device(name='Multiclamp 700B amplifier', manufacturer='Molecular Devices', model_name='700B', distribution=Distribution('https://www.moleculardevices.com/sites/default/files/en/assets/data-sheets/dd/cns/multiclamp-700b-microelectrode-amplifier.pdf'), id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/electrophysiology/device/v0.1.2/2a4b755d-1e34-4e33-b6bc-e823206c5214), stimulation=ElectrophysiologicalStimulation(name='Stimulation for hbp-00806.hbp_3.cell1', electrophysiological_stimulus=ElectrophysiologicalStimulus(name='Stimulus for hbp-00806.hbp_3.cell1', description='Whole cell current - clamp recordings were performed from the pyramidal layer of the hippocampal CA1 region using a Multiclamp 700B amplifier (Molecular Devices, USA). The data were digitized at 10 kHz using Spike2 software (CED UK) in conjunction with a Micro 1401 (CED UK). No bias current was injected during recordings and the membrane potential was not corrected for the liquid junction potential. Simultaneously, LFP was recorded from the pyramidal cell layer in the contralateral hippocampal CA1 region using a Multiclamp 700B amplifier.', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/optophysiology/electrophysiologicalstimulus/v0.1.0/44379a58-3ad5-4a47-8cb4-9d80764e5409), protocol=Protocol(name='Whole cell current - clamp recordings', steps=Step(name='Whole cell current - clamp recordings', sequence_number=1, description='Whole cell current - clamp recordings were performed from the pyramidal layer of the hippocampal CA1 region using a Multiclamp 700B amplifier (Molecular Devices, USA). The data were digitized at 10 kHz using Spike2 software (CED UK) in conjunction with a Micro 1401 (CED UK). No bias current was injected during recordings and the membrane potential was not corrected for the liquid junction potential. Simultaneously, LFP was recorded from the pyramidal cell layer in the contralateral hippocampal CA1 region using a Multiclamp 700B amplifier.', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/step/v0.1.1/87294db5-69f2-49fb-9f00-75975deadc41), author=[Person(family_name='Jelitai', given_name='Marta', email='jelitai@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/ad280f5e-d866-4886-aee8-ab120fc56daa), Person(family_name='Komlosi', given_name='Ferenc', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/92ceae24-5c2d-4629-949d-82c8488b5312), Person(family_name='Kali', given_name='Szabolcs', email='kali@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/4c25a4e2-6742-4c1d-a625-7ef46b5768c4), Person(family_name='Freund', given_name='Tamas', email='freund@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/10d93c77-07bc-481c-a56f-43577fda73eb), Person(family_name='Varga', given_name='Viktor', email='varga.viktor@koki.mta.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/f8fb24b1-4d86-4965-9368-f2a5896e5f0f)], id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/protocol/v0.1.6/d296aac3-ba95-48fa-bea6-bdde0f34d176), id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/optophysiology/electrophysiologicalstimulation/v0.1.0/bbedef4c-6bda-40ea-a4ee-29329b5e1025), id=https://nexus-int.humanbra ...
# filename Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_3_cell1_ephys__160722_cell1.mat
# file_url Freund_SGA1_T1.2.5/HC-awake-ephys/HBP_3/cell1/ephys/Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_3_cell1_ephys__160722_cell1.mat
# file_location https://object.cscs.ch/v1/AUTH_63ea6845b1d34ad7a43c8158d9572867/Freund_SGA1_T1.2.5/HC-awake-ephys/HBP_3/cell1/ephys/Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_3_cell1_ephys__160722_cell1.mat
# first .mat
# ...
# filename Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_28_cell1_ephys__170726_c1_000.mat
# file_url Freund_SGA1_T1.2.5/HC-awake-ephys/HBP_28/cell1/ephys/Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_28_cell1_ephys__170726_c1_000.mat
# file_location https://object.cscs.ch/v1/AUTH_63ea6845b1d34ad7a43c8158d9572867/Freund_SGA1_T1.2.5/HC-awake-ephys/HBP_28/cell1/ephys/Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_28_cell1_ephys__170726_c1_000.mat
# first .mat
# QualifiedMultiTraceGeneration(name='Metadata for whole cell recordings in hbp-00806.HBP_28.cell1', stimulus_experiment=PatchClampExperiment(name='Whole cell recordings in hbp-00806.hbp_28.cell1', recorded_cell=PatchedCell(name='hbp-00806.HBP_28.cell1', brain_location=[BrainRegion('hippocampus CA1', 'http://uri.interlex.org/ilx_0101520')], cell_type=CellType('hippocampus CA1 pyramidal cell', 'http://uri.interlex.org/ilx_0105031'), id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/experiment/patchedcell/v0.1.0/f15af2c6-fd68-439e-9361-e2138d6368fe), acquisition_device=Device(name='Multiclamp 700B amplifier', manufacturer='Molecular Devices', model_name='700B', distribution=Distribution('https://www.moleculardevices.com/sites/default/files/en/assets/data-sheets/dd/cns/multiclamp-700b-microelectrode-amplifier.pdf'), id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/electrophysiology/device/v0.1.2/2a4b755d-1e34-4e33-b6bc-e823206c5214), stimulation=ElectrophysiologicalStimulation(name='Stimulation for hbp-00806.hbp_28.cell1', electrophysiological_stimulus=ElectrophysiologicalStimulus(name='Stimulus for hbp-00806.hbp_28.cell1', description='Whole cell current - clamp recordings were performed from the pyramidal layer of the hippocampal CA1 region using a Multiclamp 700B amplifier (Molecular Devices, USA). The data were digitized at 10 kHz using Spike2 software (CED UK) in conjunction with a Micro 1401 (CED UK). No bias current was injected during recordings and the membrane potential was not corrected for the liquid junction potential. Simultaneously, LFP was recorded from the pyramidal cell layer in the contralateral hippocampal CA1 region using a Multiclamp 700B amplifier.', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/optophysiology/electrophysiologicalstimulus/v0.1.0/15f0590f-864e-4c3b-a36f-3ea6aad94063), protocol=Protocol(name='Whole cell current - clamp recordings', steps=Step(name='Whole cell current - clamp recordings', sequence_number=1, description='Whole cell current - clamp recordings were performed from the pyramidal layer of the hippocampal CA1 region using a Multiclamp 700B amplifier (Molecular Devices, USA). The data were digitized at 10 kHz using Spike2 software (CED UK) in conjunction with a Micro 1401 (CED UK). No bias current was injected during recordings and the membrane potential was not corrected for the liquid junction potential. Simultaneously, LFP was recorded from the pyramidal cell layer in the contralateral hippocampal CA1 region using a Multiclamp 700B amplifier.', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/step/v0.1.1/87294db5-69f2-49fb-9f00-75975deadc41), author=[Person(family_name='Jelitai', given_name='Marta', email='jelitai@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/ad280f5e-d866-4886-aee8-ab120fc56daa), Person(family_name='Komlosi', given_name='Ferenc', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/92ceae24-5c2d-4629-949d-82c8488b5312), Person(family_name='Kali', given_name='Szabolcs', email='kali@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/4c25a4e2-6742-4c1d-a625-7ef46b5768c4), Person(family_name='Freund', given_name='Tamas', email='freund@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/10d93c77-07bc-481c-a56f-43577fda73eb), Person(family_name='Varga', given_name='Viktor', email='varga.viktor@koki.mta.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/f8fb24b1-4d86-4965-9368-f2a5896e5f0f)], id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/protocol/v0.1.6/d296aac3-ba95-48fa-bea6-bdde0f34d176), id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/optophysiology/electrophysiologicalstimulation/v0.1.0/8ee121dd-fa3c-4f2c-b130-bff5f193811a), id=https://nexus-int.hum ...
# filename Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_28_cell1_ephys__170726_c1_002.mat
# file_url Freund_SGA1_T1.2.5/HC-awake-ephys/HBP_28/cell1/ephys/Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_28_cell1_ephys__170726_c1_002.mat
# file_location https://object.cscs.ch/v1/AUTH_63ea6845b1d34ad7a43c8158d9572867/Freund_SGA1_T1.2.5/HC-awake-ephys/HBP_28/cell1/ephys/Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_28_cell1_ephys__170726_c1_002.mat
# first .mat
# QualifiedMultiTraceGeneration(name='Metadata for whole cell recordings in hbp-00806.HBP_28.cell1', stimulus_experiment=PatchClampExperiment(name='Whole cell recordings in hbp-00806.hbp_28.cell1', recorded_cell=PatchedCell(name='hbp-00806.HBP_28.cell1', brain_location=[BrainRegion('hippocampus CA1', 'http://uri.interlex.org/ilx_0101520')], cell_type=CellType('hippocampus CA1 pyramidal cell', 'http://uri.interlex.org/ilx_0105031'), id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/experiment/patchedcell/v0.1.0/f15af2c6-fd68-439e-9361-e2138d6368fe), acquisition_device=Device(name='Multiclamp 700B amplifier', manufacturer='Molecular Devices', model_name='700B', distribution=Distribution('https://www.moleculardevices.com/sites/default/files/en/assets/data-sheets/dd/cns/multiclamp-700b-microelectrode-amplifier.pdf'), id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/electrophysiology/device/v0.1.2/2a4b755d-1e34-4e33-b6bc-e823206c5214), stimulation=ElectrophysiologicalStimulation(name='Stimulation for hbp-00806.hbp_28.cell1', electrophysiological_stimulus=ElectrophysiologicalStimulus(name='Stimulus for hbp-00806.hbp_28.cell1', description='Whole cell current - clamp recordings were performed from the pyramidal layer of the hippocampal CA1 region using a Multiclamp 700B amplifier (Molecular Devices, USA). The data were digitized at 10 kHz using Spike2 software (CED UK) in conjunction with a Micro 1401 (CED UK). No bias current was injected during recordings and the membrane potential was not corrected for the liquid junction potential. Simultaneously, LFP was recorded from the pyramidal cell layer in the contralateral hippocampal CA1 region using a Multiclamp 700B amplifier.', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/optophysiology/electrophysiologicalstimulus/v0.1.0/15f0590f-864e-4c3b-a36f-3ea6aad94063), protocol=Protocol(name='Whole cell current - clamp recordings', steps=Step(name='Whole cell current - clamp recordings', sequence_number=1, description='Whole cell current - clamp recordings were performed from the pyramidal layer of the hippocampal CA1 region using a Multiclamp 700B amplifier (Molecular Devices, USA). The data were digitized at 10 kHz using Spike2 software (CED UK) in conjunction with a Micro 1401 (CED UK). No bias current was injected during recordings and the membrane potential was not corrected for the liquid junction potential. Simultaneously, LFP was recorded from the pyramidal cell layer in the contralateral hippocampal CA1 region using a Multiclamp 700B amplifier.', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/step/v0.1.1/87294db5-69f2-49fb-9f00-75975deadc41), author=[Person(family_name='Jelitai', given_name='Marta', email='jelitai@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/ad280f5e-d866-4886-aee8-ab120fc56daa), Person(family_name='Komlosi', given_name='Ferenc', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/92ceae24-5c2d-4629-949d-82c8488b5312), Person(family_name='Kali', given_name='Szabolcs', email='kali@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/4c25a4e2-6742-4c1d-a625-7ef46b5768c4), Person(family_name='Freund', given_name='Tamas', email='freund@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/10d93c77-07bc-481c-a56f-43577fda73eb), Person(family_name='Varga', given_name='Viktor', email='varga.viktor@koki.mta.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/f8fb24b1-4d86-4965-9368-f2a5896e5f0f)], id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/protocol/v0.1.6/d296aac3-ba95-48fa-bea6-bdde0f34d176), id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/optophysiology/electrophysiologicalstimulation/v0.1.0/8ee121dd-fa3c-4f2c-b130-bff5f193811a), id=https://nexus-int.hum ...
# filename Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_28_cell1_ephys__170726_c1_003.mat
# file_url Freund_SGA1_T1.2.5/HC-awake-ephys/HBP_28/cell1/ephys/Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_28_cell1_ephys__170726_c1_003.mat
# file_location https://object.cscs.ch/v1/AUTH_63ea6845b1d34ad7a43c8158d9572867/Freund_SGA1_T1.2.5/HC-awake-ephys/HBP_28/cell1/ephys/Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_28_cell1_ephys__170726_c1_003.mat
# first .mat
# QualifiedMultiTraceGeneration(name='Metadata for whole cell recordings in hbp-00806.HBP_28.cell1', stimulus_experiment=PatchClampExperiment(name='Whole cell recordings in hbp-00806.hbp_28.cell1', recorded_cell=PatchedCell(name='hbp-00806.HBP_28.cell1', brain_location=[BrainRegion('hippocampus CA1', 'http://uri.interlex.org/ilx_0101520')], cell_type=CellType('hippocampus CA1 pyramidal cell', 'http://uri.interlex.org/ilx_0105031'), id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/experiment/patchedcell/v0.1.0/f15af2c6-fd68-439e-9361-e2138d6368fe), acquisition_device=Device(name='Multiclamp 700B amplifier', manufacturer='Molecular Devices', model_name='700B', distribution=Distribution('https://www.moleculardevices.com/sites/default/files/en/assets/data-sheets/dd/cns/multiclamp-700b-microelectrode-amplifier.pdf'), id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/electrophysiology/device/v0.1.2/2a4b755d-1e34-4e33-b6bc-e823206c5214), stimulation=ElectrophysiologicalStimulation(name='Stimulation for hbp-00806.hbp_28.cell1', electrophysiological_stimulus=ElectrophysiologicalStimulus(name='Stimulus for hbp-00806.hbp_28.cell1', description='Whole cell current - clamp recordings were performed from the pyramidal layer of the hippocampal CA1 region using a Multiclamp 700B amplifier (Molecular Devices, USA). The data were digitized at 10 kHz using Spike2 software (CED UK) in conjunction with a Micro 1401 (CED UK). No bias current was injected during recordings and the membrane potential was not corrected for the liquid junction potential. Simultaneously, LFP was recorded from the pyramidal cell layer in the contralateral hippocampal CA1 region using a Multiclamp 700B amplifier.', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/optophysiology/electrophysiologicalstimulus/v0.1.0/15f0590f-864e-4c3b-a36f-3ea6aad94063), protocol=Protocol(name='Whole cell current - clamp recordings', steps=Step(name='Whole cell current - clamp recordings', sequence_number=1, description='Whole cell current - clamp recordings were performed from the pyramidal layer of the hippocampal CA1 region using a Multiclamp 700B amplifier (Molecular Devices, USA). The data were digitized at 10 kHz using Spike2 software (CED UK) in conjunction with a Micro 1401 (CED UK). No bias current was injected during recordings and the membrane potential was not corrected for the liquid junction potential. Simultaneously, LFP was recorded from the pyramidal cell layer in the contralateral hippocampal CA1 region using a Multiclamp 700B amplifier.', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/step/v0.1.1/87294db5-69f2-49fb-9f00-75975deadc41), author=[Person(family_name='Jelitai', given_name='Marta', email='jelitai@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/ad280f5e-d866-4886-aee8-ab120fc56daa), Person(family_name='Komlosi', given_name='Ferenc', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/92ceae24-5c2d-4629-949d-82c8488b5312), Person(family_name='Kali', given_name='Szabolcs', email='kali@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/4c25a4e2-6742-4c1d-a625-7ef46b5768c4), Person(family_name='Freund', given_name='Tamas', email='freund@koki.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/10d93c77-07bc-481c-a56f-43577fda73eb), Person(family_name='Varga', given_name='Viktor', email='varga.viktor@koki.mta.hu', id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/person/v0.1.0/f8fb24b1-4d86-4965-9368-f2a5896e5f0f)], id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/core/protocol/v0.1.6/d296aac3-ba95-48fa-bea6-bdde0f34d176), id=https://nexus-int.humanbrainproject.org/v0/data/neuralactivity/optophysiology/electrophysiologicalstimulation/v0.1.0/8ee121dd-fa3c-4f2c-b130-bff5f193811a), id=https://nexus-int.hum ...

# %%
print(f"Run on {datetime.now()} on{client.nexus_endpoint}")
# Out:
# Run on 2020-06-23 10:38:24.995896 onhttps://nexus-int.humanbrainproject.org/v0

# %%
"""
file = 'Freund_SGA1_T1.2.5/HC-awake-ephys/HBP_2/cell1/ephys/Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_2_cell1_ephys__160713_cell1.mat'
with h5py.File(file, 'r') as f:
    channel_names = [key for key in f.keys() if 'Ch' in key]
    n_segments=len(channel_names)
    data_units = 'mV'
    time_step = QuantitativeValue(1/list(f['Unit']['interval'])[0][0],"ms")

    print(channel_names)
    print(n_segments)
    print(data_units)
    print(time_step)
    f.close()"""
# Out:
# '\nfile = \'Freund_SGA1_T1.2.5/HC-awake-ephys/HBP_2/cell1/ephys/Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_2_cell1_ephys__160713_cell1.mat\'\nwith h5py.File(file, \'r\') as f:\n    channel_names = [key for key in f.keys() if \'Ch\' in key]\n    n_segments=len(channel_names)\n    data_units = \'mV\'\n    time_step = QuantitativeValue(1/list(f[\'Unit\'][\'interval\'])[0][0],"ms")\n\n    print(channel_names)\n    print(n_segments)\n    print(data_units)\n    print(time_step)\n    f.close()'

# %%
"""file = 'Freund_SGA1_T1.2.5/HC-awake-ephys/HBP_1/cell1/ephys/Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_1_cell1_ephys__160712_cell1.s2rx'
io = AsciiSignalIO(file)
data = io.read_block()
n_segments = len(data.segments)
sigs = data.segments[0].analogsignals
channel_names = [sig.name for sig in sigs]
units = [sig.units.dimensionality.string for sig in sigs]
time_step = float(sigs[0].sampling_period.rescale("ms"))
print(time_step)
print(channel_names)
print(units)
# get_io, RawBinarySignalIO, AsciiSignalIO, Spike2IO, NeoMatlabIO, BlackrockIO, NeoHdf5IO
"""
# Out:
# 'file = \'Freund_SGA1_T1.2.5/HC-awake-ephys/HBP_1/cell1/ephys/Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_1_cell1_ephys__160712_cell1.s2rx\'\nio = AsciiSignalIO(file)\ndata = io.read_block()\nn_segments = len(data.segments)\nsigs = data.segments[0].analogsignals\nchannel_names = [sig.name for sig in sigs]\nunits = [sig.units.dimensionality.string for sig in sigs]\ntime_step = float(sigs[0].sampling_period.rescale("ms"))\nprint(time_step)\nprint(channel_names)\nprint(units)\n# get_io, RawBinarySignalIO, AsciiSignalIO, Spike2IO, NeoMatlabIO, BlackrockIO, NeoHdf5IO\n'

# %%
"""file= 'Freund_SGA1_T1.2.5/HC-awake-ephys/HBP_2/cell2/ephys/Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_2_cell2_ephys__160713_cell2.mat'
io = RawBinarySignalIO(file)
data = io.read_block()
n_segments = len(data.segments)
sigs = data.segments[0].analogsignals
channel_names = [sig.name for sig in sigs]
units = [sig.units.dimensionality.string for sig in sigs]
time_step = float(sigs[0].sampling_period.rescale("ms"))
print(time_step)
print(channel_names)
print(units)"""
# get_io, RawBinarySignalIO, AsciiSignalIO, Spike2IO, NeoMatlabIO, BlackrockIO, NeoHdf5IO
# Out:
# 'file= \'Freund_SGA1_T1.2.5/HC-awake-ephys/HBP_2/cell2/ephys/Freund_SGA1_T1.2.5_HC-awake-ephys_HBP_2_cell2_ephys__160713_cell2.mat\'\nio = RawBinarySignalIO(file)\ndata = io.read_block()\nn_segments = len(data.segments)\nsigs = data.segments[0].analogsignals\nchannel_names = [sig.name for sig in sigs]\nunits = [sig.units.dimensionality.string for sig in sigs]\ntime_step = float(sigs[0].sampling_period.rescale("ms"))\nprint(time_step)\nprint(channel_names)\nprint(units)'

# %%
"""                with h5py.File(file_url, 'r') as f:
                    channel_names = [key for key in f.keys() if 'Ch' in key]
                    n_segments=len(channel_names)
                    data_units = 'mV'
                    time_step = QuantitativeValue(1/list(f['Unit']['interval'])[0][0],"ms")

                    print(channel_names)
                    print(n_segments)
                    print(data_units)
                    print(time_step)
                f.close()
"""
# Out:
# '                with h5py.File(file_url, \'r\') as f:\n                    channel_names = [key for key in f.keys() if \'Ch\' in key]\n                    n_segments=len(channel_names)\n                    data_units = \'mV\'\n                    time_step = QuantitativeValue(1/list(f[\'Unit\'][\'interval\'])[0][0],"ms")\n\n                    print(channel_names)\n                    print(n_segments)\n                    print(data_units)\n                    print(time_step)\n                f.close()\n'
